# %% [markdown]
# # Data Augmentation v3
# This notebook performs data augmentation on the dataset by creating an augmented copy of each image in the original dataset. Original dataset images are taken from the ```dataset``` folder, while original and augmented images are saved to the ```dataset-augmented-v3``` folder.
#
# This second version generates more data than the ```dataset-augmented``` notebook and folder. Whereas ```dataset-augmented``` generates 2x the original dataset, this notebook generates 4x the original dataset.

# %% [markdown]
# ### Import Libraries

# %%
import os
import numpy as np
import pandas as pd
from PIL import Image
from io import StringIO
from matplotlib import pyplot as plt
import shutil
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torchvision.utils import make_grid, save_image
from torch.utils.data import Dataset, DataLoader
# Out:
# C:\Users\Irish\anaconda3\envs\conv_env\lib\site-packages\torchvision\io\image.py:13: UserWarning: Failed to load image Python extension: [WinError 127] The specified procedure could not be found
#   warn(f"Failed to load image Python extension: {e}")

# %% [markdown]
# ### Define Variables & Helper Functions

# %%
# Folders for input (original images) and output (original + augmented images)
in_folder = r"dataset/"
out_folder = r"dataset-augmented-v2/"

# %%
# Set seed for PyTorch random number generation to create reproducible results
torch.manual_seed(5)

# %%
# Convert PIL Image to tensor
to_tensor = transforms.Compose([
    # Convert PIL Image to tensor and scale to [0, 1] through max normalization
    # (i.e. for every pixel in image, new_pixel_value = pixel/255)
    transforms.ToTensor()
])

translation_matrix = torch.tensor([[0, 1, 0], [0, 0, 1], [1, 0, 0]])

# Transformations to apply to inputs, where one is randomly chosen and applied per image
augmentations = transforms.RandomChoice([
    # Rotate by a random amount within -3 to -1 degrees
    transforms.RandomRotation(degrees=(-3, -1), fill=255), 
    
    # Rotate by a random amount within 1 to 3 degrees
    transforms.RandomRotation(degrees=(1, 3), fill=255), 
    
    # Translate horizontally by a random percentage between -15% and 15% and
    # vertically by a random percentage between -15% and 15%
    transforms.RandomAffine(degrees=0, translate=(0.15, 0.15), fill=255), 
    
    # Horizontally flips the image
    transforms.RandomHorizontalFlip(p=1)
])

# %%
# Helper function to get ground truth class of an image
def get_img_labels(img_dir):
    labels = ''
    
    for filename in os.listdir(img_dir):
        # If image has no metastasis
        if (filename[5] == '0'):
            labels += filename + ",0\n"
            
        # If image has metastasis
        else:
            labels += filename + ",1\n"
        
    return labels

# %% [markdown]
# ### Augment Data

# %%
# Image dataset
class AugmentedDataset(Dataset):
    def __init__(self, img_dir, to_tensor, augment):
        self.img_dir = img_dir
        self.img_labels = pd.read_csv(StringIO(get_img_labels(img_dir)), sep=",", header=None)
        self.to_tensor = to_tensor
        self.augment = augmentations

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        # Generate image filepath
        filename = self.img_labels.iloc[idx, 0]
        img_path = self.img_dir + "/" + filename
        
        # Augment image
        image = Image.open(img_path).convert("RGB")
        image = self.to_tensor(image)
        image = self.augment(image)
        
        # Determine ground truth class (metastasis or no metastasis)
        label = self.img_labels.iloc[idx, 1]
        return image, label, filename

# %%
# Dataset and dataloader for images
data = AugmentedDataset(img_dir=in_folder, to_tensor=to_tensor, augment=augmentations)
loader = DataLoader(data, batch_size=10, shuffle=True)

# %% [markdown]
# ### Show Sample of Augmented Data

# %%
# Show random augmented images and their ground truth classes
dataiter = iter(loader)
images, labels, filenames = next(dataiter)

plt.axis('off')
plt.imshow(make_grid(images).permute(1,2,0))
print("Classes: " + ' '.join(f'{labels[j]}' for j in range(len(labels))))
print("Original files:\n" + '\n'.join(f'{filenames[j]}' for j in range(len(filenames))))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Classes: 1 0 1 1 0 1 0 0 0 0
# Original files:
# 0718-1-A.tif
# 0083-0-P.tif
# 0408-1-A.tif
# 0422-1-A.tif
# 0375-0-P.tif
# 0994-1-A.tif
# 0594-0-A.tif
# 1031-0-P.tif
# 0091-0-P.tif
# 0935-0-A.tif

# %% [markdown]
# ### Save Augmented Images to Output Folder

# %%
# Copy original images to output folder
for filename in os.listdir(in_folder):
    in_file = os.path.join(in_folder, filename)
    shutil.copy(in_file, out_folder)

# %%
# Get index of last original image
last_filename = os.listdir(in_folder)[-1]
img_index = int(last_filename[0:4])

# %%
# Delete all previous copies of augmented images in folder (if any)
for filename in os.listdir(out_folder):
    if (int(filename[0:4]) > img_index):
        os.remove(os.path.join(out_folder, filename))

# %%
for batch_index, batch_data in enumerate(loader):
    # Get the images, labels, and filenames in the current batch
    images, labels, orig_filenames = batch_data
    
    # Iterate over each image in the original dataset
    for i in range(len(images)):
        
        # Create 7 augmented copies per original image in the dataset
        for j in range(7):
            
            # Create filename for augmented image
            img_index += 1
            new_filename = str(img_index) + orig_filenames[i][4:]
            img_path = out_folder + "/" + new_filename

            # Save augmented image
            save_image(images[i], img_path)
            print(f"Saved augmented copy of {orig_filenames[i]} as {new_filename} in {out_folder}")
# Out:
# Saved augmented copy of 0331-1-A.tif as 1226-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0331-1-A.tif as 1227-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0331-1-A.tif as 1228-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0331-1-A.tif as 1229-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0331-1-A.tif as 1230-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0331-1-A.tif as 1231-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0331-1-A.tif as 1232-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0188-1-A.tif as 1233-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0188-1-A.tif as 1234-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0188-1-A.tif as 1235-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0188-1-A.tif as 1236-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0188-1-A.tif as 1237-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0188-1-A.tif as 1238-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0188-1-A.tif as 1239-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 1225-1-P.tif as 1240-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1225-1-P.tif as 1241-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1225-1-P.tif as 1242-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1225-1-P.tif as 1243-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1225-1-P.tif as 1244-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1225-1-P.tif as 1245-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1225-1-P.tif as 1246-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1224-1-P.tif as 1247-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1224-1-P.tif as 1248-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1224-1-P.tif as 1249-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1224-1-P.tif as 1250-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1224-1-P.tif as 1251-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1224-1-P.tif as 1252-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1224-1-P.tif as 1253-1-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0786-0-A.tif as 1254-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0786-0-A.tif as 1255-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0786-0-A.tif as 1256-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0786-0-A.tif as 1257-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0786-0-A.tif as 1258-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0786-0-A.tif as 1259-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0786-0-A.tif as 1260-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0361-0-P.tif as 1261-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0361-0-P.tif as 1262-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0361-0-P.tif as 1263-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0361-0-P.tif as 1264-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0361-0-P.tif as 1265-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0361-0-P.tif as 1266-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0361-0-P.tif as 1267-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0126-0-A.tif as 1268-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0126-0-A.tif as 1269-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0126-0-A.tif as 1270-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0126-0-A.tif as 1271-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0126-0-A.tif as 1272-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0126-0-A.tif as 1273-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0126-0-A.tif as 1274-0-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0663-0-P.tif as 1275-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0663-0-P.tif as 1276-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0663-0-P.tif as 1277-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0663-0-P.tif as 1278-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0663-0-P.tif as 1279-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0663-0-P.tif as 1280-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0663-0-P.tif as 1281-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1070-0-P.tif as 1282-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1070-0-P.tif as 1283-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1070-0-P.tif as 1284-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1070-0-P.tif as 1285-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1070-0-P.tif as 1286-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1070-0-P.tif as 1287-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1070-0-P.tif as 1288-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 0971-1-A.tif as 1289-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0971-1-A.tif as 1290-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0971-1-A.tif as 1291-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0971-1-A.tif as 1292-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0971-1-A.tif as 1293-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0971-1-A.tif as 1294-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 0971-1-A.tif as 1295-1-A.tif in dataset-augmented-v2/
# Saved augmented copy of 1140-0-P.tif as 1296-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 1140-0-P.tif as 1297-0-P.tif in dataset-augmented-v2/
# Saved augmented copy of 